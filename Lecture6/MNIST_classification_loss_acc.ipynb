# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# Define hyperparameters
input_size = 28*28          # img_size = (28,28) ---> 28*28=784 in total
num_classes = 10            # number of output classes discrete range [0,9]
hidden_size = [100]     # number of neurons at hidden layer
num_epochs = 50
batch_size = 128
lr = 1e-3 # learning rate

# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_data = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Split the dataset into train, validation, and test sets
train_size = int(0.8 * len(train_data))
val_size = len(train_data) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_data, [train_size, val_size])
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Define a simple neural network model
class FCNN(nn.Module):
    def __init__(self, input_size, hidden_sizes, output_size):
        super(FCNN, self).__init__()
        layer_sizes = [input_size] + hidden_sizes + [output_size]
        layers = []
        for i in range(len(layer_sizes) - 1):
            layers.append(nn.Linear(layer_sizes[i], layer_sizes[i+1]))
            if i < len(layer_sizes) - 2:
                layers.append(nn.ReLU())  # Using ReLU activation function
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(-1, 28*28)
        return self.model(x)

# Create a model
model = FCNN(input_size, hidden_size, num_classes)

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# Training loop
train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_losses.append(train_loss)
    train_acc = train_correct / train_total
    train_accs.append(train_acc)

    model.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
    
    val_loss = running_val_loss / len(val_loader)
    val_losses.append(val_loss)
    val_acc = val_correct / val_total
    val_accs.append(val_acc)

    print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss}, Val Loss: {val_loss}, Train accuracy: {train_acc:.4f}, Val accuracy: {val_acc:.4f}')

# Plot the training and validation loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), train_losses, label='Training Loss')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
plt.ylim(0, 2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), train_accs, label='Training Accuracy')
plt.plot(range(1, num_epochs+1), val_accs, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/50, Train Loss: 0.5095363507270813, Val Loss: 0.3288067693405963, Train accuracy: 0.8574, Val accuracy: 0.9028
# Epoch 2/50, Train Loss: 0.29256149812539417, Val Loss: 0.258375716019184, Train accuracy: 0.9140, Val accuracy: 0.9247
# Epoch 3/50, Train Loss: 0.2296916404167811, Val Loss: 0.22246404689677218, Train accuracy: 0.9340, Val accuracy: 0.9353
# Epoch 4/50, Train Loss: 0.1880176036953926, Val Loss: 0.17683373748304995, Train accuracy: 0.9442, Val accuracy: 0.9473
# Epoch 5/50, Train Loss: 0.15926650655269622, Val Loss: 0.15467699533922874, Train accuracy: 0.9535, Val accuracy: 0.9532
# Epoch 6/50, Train Loss: 0.13632831280926863, Val Loss: 0.15910203818311083, Train accuracy: 0.9592, Val accuracy: 0.9530
# Epoch 7/50, Train Loss: 0.12056050398449103, Val Loss: 0.13059154937558987, Train accuracy: 0.9634, Val accuracy: 0.9606
# Epoch 8/50, Train Loss: 0.10609179762005806, Val Loss: 0.12027344216612425, Train accuracy: 0.9684, Val accuracy: 0.9637
# Epoch 9/50, Train Loss: 0.09328862984478474, Val Loss: 0.12270756549340614, Train accuracy: 0.9716, Val accuracy: 0.9633
# Epoch 10/50, Train Loss: 0.08702721117436886, Val Loss: 0.11376552313486947, Train accuracy: 0.9730, Val accuracy: 0.9660
# Epoch 11/50, Train Loss: 0.07947306085626284, Val Loss: 0.11744900021028329, Train accuracy: 0.9753, Val accuracy: 0.9647
# Epoch 12/50, Train Loss: 0.07395517821361622, Val Loss: 0.10462070902452823, Train accuracy: 0.9769, Val accuracy: 0.9686
# Epoch 13/50, Train Loss: 0.06864639522135257, Val Loss: 0.10712402813295101, Train accuracy: 0.9784, Val accuracy: 0.9684
# Epoch 14/50, Train Loss: 0.061320865926643216, Val Loss: 0.10037248639112457, Train accuracy: 0.9811, Val accuracy: 0.9692
# Epoch 15/50, Train Loss: 0.05891980092972517, Val Loss: 0.1060655981975984, Train accuracy: 0.9808, Val accuracy: 0.9683
# Epoch 16/50, Train Loss: 0.05364511688301961, Val Loss: 0.10319267809787329, Train accuracy: 0.9828, Val accuracy: 0.9716
# Epoch 17/50, Train Loss: 0.05165808160727223, Val Loss: 0.10119768206347177, Train accuracy: 0.9831, Val accuracy: 0.9702
# Epoch 18/50, Train Loss: 0.049388048021743694, Val Loss: 0.10826267470466963, Train accuracy: 0.9838, Val accuracy: 0.9689
# Epoch 19/50, Train Loss: 0.0448873299403737, Val Loss: 0.10304175029964523, Train accuracy: 0.9853, Val accuracy: 0.9695
# Epoch 20/50, Train Loss: 0.04105936856816212, Val Loss: 0.10620261233379232, Train accuracy: 0.9872, Val accuracy: 0.9693
# Epoch 21/50, Train Loss: 0.04075174177934726, Val Loss: 0.10504807294049162, Train accuracy: 0.9866, Val accuracy: 0.9712
# Epoch 22/50, Train Loss: 0.035996168654412034, Val Loss: 0.10928541255441118, Train accuracy: 0.9885, Val accuracy: 0.9696
# Epoch 23/50, Train Loss: 0.0348750503876557, Val Loss: 0.10349752019813403, Train accuracy: 0.9892, Val accuracy: 0.9735
# Epoch 24/50, Train Loss: 0.03257795199627678, Val Loss: 0.1090000787987671, Train accuracy: 0.9896, Val accuracy: 0.9710
# Epoch 25/50, Train Loss: 0.03127072771762808, Val Loss: 0.10913824588753918, Train accuracy: 0.9898, Val accuracy: 0.9712
# Epoch 26/50, Train Loss: 0.028462825391441585, Val Loss: 0.11438843735711689, Train accuracy: 0.9908, Val accuracy: 0.9698
# Epoch 27/50, Train Loss: 0.03024019781500101, Val Loss: 0.11455929409118092, Train accuracy: 0.9901, Val accuracy: 0.9701
# Epoch 28/50, Train Loss: 0.026557496378198268, Val Loss: 0.11869540851206538, Train accuracy: 0.9911, Val accuracy: 0.9688
# Epoch 29/50, Train Loss: 0.02604095384913186, Val Loss: 0.11248574921108306, Train accuracy: 0.9911, Val accuracy: 0.9710
# Epoch 30/50, Train Loss: 0.025633428149546188, Val Loss: 0.14000304067071448, Train accuracy: 0.9915, Val accuracy: 0.9661
# Epoch 31/50, Train Loss: 0.023324078989836076, Val Loss: 0.1054568351642724, Train accuracy: 0.9921, Val accuracy: 0.9729
# Epoch 32/50, Train Loss: 0.022166898858733474, Val Loss: 0.11020702404029509, Train accuracy: 0.9930, Val accuracy: 0.9735
# Epoch 33/50, Train Loss: 0.020675883459548156, Val Loss: 0.11301629928416236, Train accuracy: 0.9933, Val accuracy: 0.9732
# Epoch 34/50, Train Loss: 0.018534428864096602, Val Loss: 0.11217866778779934, Train accuracy: 0.9941, Val accuracy: 0.9718
# Epoch 35/50, Train Loss: 0.02214480256785949, Val Loss: 0.119908355424141, Train accuracy: 0.9921, Val accuracy: 0.9718
# Epoch 36/50, Train Loss: 0.02024502519937232, Val Loss: 0.12978016476622445, Train accuracy: 0.9929, Val accuracy: 0.9706
# Epoch 37/50, Train Loss: 0.017788319083862008, Val Loss: 0.1181361446692113, Train accuracy: 0.9942, Val accuracy: 0.9717
# Epoch 38/50, Train Loss: 0.015327219662877421, Val Loss: 0.13197380035342846, Train accuracy: 0.9949, Val accuracy: 0.9698
# Epoch 39/50, Train Loss: 0.015553619904133181, Val Loss: 0.1200117768541454, Train accuracy: 0.9948, Val accuracy: 0.9738
# Epoch 40/50, Train Loss: 0.018001137585689626, Val Loss: 0.13046274273755384, Train accuracy: 0.9938, Val accuracy: 0.9704
# Epoch 41/50, Train Loss: 0.016449216812849044, Val Loss: 0.13359429837858422, Train accuracy: 0.9942, Val accuracy: 0.9699
# Epoch 42/50, Train Loss: 0.015756505633083482, Val Loss: 0.14378262775890688, Train accuracy: 0.9949, Val accuracy: 0.9692
# Epoch 43/50, Train Loss: 0.011212348388197521, Val Loss: 0.12164238978553801, Train accuracy: 0.9966, Val accuracy: 0.9738
# Epoch 44/50, Train Loss: 0.014120822612196207, Val Loss: 0.1475739917975474, Train accuracy: 0.9956, Val accuracy: 0.9677
# Epoch 45/50, Train Loss: 0.013481673718895764, Val Loss: 0.12905218648387395, Train accuracy: 0.9953, Val accuracy: 0.9724
# Epoch 46/50, Train Loss: 0.014076435997306059, Val Loss: 0.1396847021508407, Train accuracy: 0.9952, Val accuracy: 0.9690
# Epoch 47/50, Train Loss: 0.01153037578977334, Val Loss: 0.13099676309688452, Train accuracy: 0.9963, Val accuracy: 0.9727
# Epoch 48/50, Train Loss: 0.0106273000993145, Val Loss: 0.14050644764458722, Train accuracy: 0.9966, Val accuracy: 0.9710
# Epoch 49/50, Train Loss: 0.011214506401641604, Val Loss: 0.14297929516141403, Train accuracy: 0.9962, Val accuracy: 0.9708
# Epoch 50/50, Train Loss: 0.015144293366232887, Val Loss: 0.1425265879816118, Train accuracy: 0.9942, Val accuracy: 0.9710
